# %%
paragraph = """Resident Evil Village[a] is a 2021 survival horror game developed and published by Capcom. It is the sequel to Resident Evil 7: Biohazard (2017) and the tenth main game of the Resident Evil series. Players control Ethan Winters, who searches for his kidnapped daughter in a village filled with mutant creatures. Village maintains survival horror elements from previous games, with players scavenging environments for items and managing resources while adding more action-oriented gameplay, with higher enemy counts and a greater emphasis on combat.

Resident Evil Village was announced at the PlayStation 5 reveal event in June 2020 and was released for PlayStation 4, PlayStation 5, Stadia, Windows, Xbox One, and Xbox Series X/S on May 7, 2021. This was followed by a macOS version and a cloud version for Nintendo Switch in October 2022, and a PlayStation VR2 version on February 22, 2023. An iOS version was released on October 30, 2023.

Resident Evil Village received generally positive reviews from critics, with praise for its gameplay, setting, and variety, but criticism for its puzzles, boss fights, and performance issues on the Windows version; the increased focus on action divided opinions. The game won year-end accolades including Game of the Year at the Golden Joystick Awards. It had sold over 10 million units by March 2024."""

# %%
import nltk
words = nltk.word_tokenize(paragraph)

# %%
tag = nltk.pos_tag(words)

# %%
nltk.ne_chunk(tag)
# Out:
# Tree('S', [('Resident', 'NNP'), ('Evil', 'NNP'), Tree('PERSON', [('Village', 'NNP')]), ('[', 'VBD'), ('a', 'DT'), (']', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('2021', 'CD'), ('survival', 'NN'), ('horror', 'NN'), ('game', 'NN'), ('developed', 'VBD'), ('and', 'CC'), ('published', 'VBN'), ('by', 'IN'), Tree('ORGANIZATION', [('Capcom', 'NNP')]), ('.', '.'), ('It', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('sequel', 'NN'), ('to', 'TO'), Tree('ORGANIZATION', [('Resident', 'NNP')]), ('Evil', 'NNP'), ('7', 'CD'), (':', ':'), ('Biohazard', 'NNP'), ('(', '('), ('2017', 'CD'), (')', ')'), ('and', 'CC'), ('the', 'DT'), ('tenth', 'NN'), ('main', 'JJ'), ('game', 'NN'), ('of', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Resident', 'NNP'), ('Evil', 'NNP')]), ('series', 'NN'), ('.', '.'), ('Players', 'NNS'), ('control', 'VBP'), Tree('PERSON', [('Ethan', 'NNP'), ('Winters', 'NNP')]), (',', ','), ('who', 'WP'), ('searches', 'VBZ'), ('for', 'IN'), ('his', 'PRP$'), ('kidnapped', 'JJ'), ('daughter', 'NN'), ('in', 'IN'), ('a', 'DT'), ('village', 'NN'), ('filled', 'VBN'), ('with', 'IN'), ('mutant', 'JJ'), ('creatures', 'NNS'), ('.', '.'), Tree('PERSON', [('Village', 'NN')]), ('maintains', 'VBZ'), ('survival', 'JJ'), ('horror', 'NN'), ('elements', 'NNS'), ('from', 'IN'), ('previous', 'JJ'), ('games', 'NNS'), (',', ','), ('with', 'IN'), ('players', 'NNS'), ('scavenging', 'VBG'), ('environments', 'NNS'), ('for', 'IN'), ('items', 'NNS'), ('and', 'CC'), ('managing', 'VBG'), ('resources', 'NNS'), ('while', 'IN'), ('adding', 'VBG'), ('more', 'JJR'), ('action-oriented', 'JJ'), ('gameplay', 'NN'), (',', ','), ('with', 'IN'), ('higher', 'JJR'), ('enemy', 'NN'), ('counts', 'NNS'), ('and', 'CC'), ('a', 'DT'), ('greater', 'JJR'), ('emphasis', 'NN'), ('on', 'IN'), ('combat', 'NN'), ('.', '.'), ('Resident', 'NNP'), ('Evil', 'NNP'), Tree('PERSON', [('Village', 'NNP')]), ('was', 'VBD'), ('announced', 'VBN'), ('at', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('PlayStation', 'NNP')]), ('5', 'CD'), ('reveal', 'NN'), ('event', 'NN'), ('in', 'IN'), ('June', 'NNP'), ('2020', 'CD'), ('and', 'CC'), ('was', 'VBD'), ('released', 'VBN'), ('for', 'IN'), ('PlayStation', 'NNP'), ('4', 'CD'), (',', ','), Tree('ORGANIZATION', [('PlayStation', 'NNP')]), ('5', 'CD'), (',', ','), Tree('GPE', [('Stadia', 'NNP')]), (',', ','), Tree('GPE', [('Windows', 'NNP')]), (',', ','), Tree('PERSON', [('Xbox', 'NNP'), ('One', 'NNP')]), (',', ','), ('and', 'CC'), Tree('PERSON', [('Xbox', 'NNP'), ('Series', 'NNP')]), ('X/S', 'NNP'), ('on', 'IN'), ('May', 'NNP'), ('7', 'CD'), (',', ','), ('2021', 'CD'), ('.', '.'), ('This', 'DT'), ('was', 'VBD'), ('followed', 'VBN'), ('by', 'IN'), ('a', 'DT'), Tree('ORGANIZATION', [('macOS', 'JJ')]), ('version', 'NN'), ('and', 'CC'), ('a', 'DT'), ('cloud', 'JJ'), ('version', 'NN'), ('for', 'IN'), Tree('PERSON', [('Nintendo', 'NNP'), ('Switch', 'NNP')]), ('in', 'IN'), ('October', 'NNP'), ('2022', 'CD'), (',', ','), ('and', 'CC'), ('a', 'DT'), Tree('ORGANIZATION', [('PlayStation', 'NNP')]), ('VR2', 'NNP'), ('version', 'NN'), ('on', 'IN'), ('February', 'NNP'), ('22', 'CD'), (',', ','), ('2023', 'CD'), ('.', '.'), ('An', 'DT'), Tree('ORGANIZATION', [('iOS', 'JJ')]), ('version', 'NN'), ('was', 'VBD'), ('released', 'VBN'), ('on', 'IN'), ('October', 'NNP'), ('30', 'CD'), (',', ','), ('2023', 'CD'), ('.', '.'), ('Resident', 'NNP'), ('Evil', 'NNP'), Tree('PERSON', [('Village', 'NNP')]), ('received', 'VBD'), ('generally', 'RB'), ('positive', 'JJ'), ('reviews', 'NNS'), ('from', 'IN'), ('critics', 'NNS'), (',', ','), ('with', 'IN'), ('praise', 'NN'), ('for', 'IN'), ('its', 'PRP$'), ('gameplay', 'NN'), (',', ','), ('setting', 'NN'), (',', ','), ('and', 'CC'), ('variety', 'NN'), (',', ','), ('but', 'CC'), ('criticism', 'NN'), ('for', 'IN'), ('its', 'PRP$'), ('puzzles', 'NNS'), (',', ','), ('boss', 'IN'), ('fights', 'NNS'), (',', ','), ('and', 'CC'), ('performance', 'NN'), ('issues', 'NNS'), ('on', 'IN'), ('the', 'DT'), ('Windows', 'NNP'), ('version', 'NN'), (';', ':'), ('the', 'DT'), (' ...
